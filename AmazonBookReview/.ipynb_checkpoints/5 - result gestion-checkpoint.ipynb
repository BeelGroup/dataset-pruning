# %%
import pandas as pd

# %%
def div(l1,a):
    l=list()
    for i in range(len(l1)):
        l.append(l1[i]/a)
    return l

# %%
def fusion(l1,l2):
    l=list()
    for i in range(len(l1)):
        l.append(l1[i]+l2[i])
    return l

# %%
def resultFinal(results):
    nbFold=5
    
    #l=list(results.values())
    n=list(results.keys())
    name=list()
    for i in range(0,len(n),nbFold):
        name.append(n[i][:-1])
    resultsFinal={}
    print (name)
    for i in range(len(n)):
        if i/nbFold-i//nbFold==0 :
            if i!=0 :
                resultsFinal[name[i//nbFold-1]]=div(lTemp,nbFold)
            lTemp=results[n[i]]
        else :
            lTemp=fusion(lTemp,results[n[i]])
        #print(lTemp[0])
    resultsFinal[name[-1]]=div(lTemp,nbFold)
    return resultsFinal

# %%
def inteName(i):
    if i==0:
        return "1-9"
    elif i<10:
        return str(int(i*10))+"-"+str(int(i*10+9))
    elif i>=50:
        return 'sup500'
    else :
        return str(int(i*10))+"-"+str(int(i*10+49))

# %%
df=pd.read_csv('data/resultRMSEbyInterval_11.csv')

# %%
df
# Out:
#          algoName  RMSE_All  RMSE_<20  RMSE_20+  RMSE_1-9  RMSE_10-19  \
# 0   BaselineOnly0  1.001623  1.046822  0.862070  1.055722    0.981371
# 1   BaselineOnly1  1.002338  1.047587  0.862629  1.056393    0.982847
# 2   BaselineOnly2  1.002221  1.047424  0.862710  1.056285    0.982269
# 3   BaselineOnly3  1.001130  1.046285  0.861707  1.055092    0.981543
# 4   BaselineOnly4  0.999729  1.042425  0.867914  1.050870    0.978958
# 5   BaselineOnly5  1.001989  1.047070  0.862889  1.055800    0.982915
# 6   BaselineOnly6  1.002223  1.047255  0.863295  1.056016    0.982857
# 7   BaselineOnly7  1.002299  1.047310  0.863453  1.056323    0.980985
# 8   BaselineOnly8  1.001303  1.046518  0.861701  1.055240    0.982420
# 9   BaselineOnly9  0.998608  1.041656  0.865494  1.050139    0.977894
# 10           SVD0  1.003656  1.046745  0.871492  1.056267    0.976526
# 11           SVD1  1.004363  1.047457  0.872216  1.056848    0.978252
# 12           SVD2  1.004298  1.047133  0.873083  1.056615    0.977225
# 13           SVD3  1.003311  1.046232  0.871702  1.055616    0.977068
# 14           SVD4  1.001080  1.041713  0.876416  1.050727    0.973805
# 15           SVD5  1.004089  1.046893  0.872961  1.056271    0.977779
# 16           SVD6  1.004181  1.047072  0.872748  1.056446    0.977990
# 17           SVD7  1.004274  1.047040  0.873268  1.056622    0.976370
# 18           SVD8  1.003393  1.046314  0.871829  1.055670    0.977372
# 19           SVD9  1.000151  1.041020  0.874627  1.050161    0.972122
# 20           NMF0  1.250977  1.335897  0.965022  1.366479    1.094671
#
#     RMSE_20-29  RMSE_30-39  RMSE_40-49  RMSE_50-59  ...  MAE_90-99  \
# 0     0.940543    0.916929    0.900573    0.872693  ...   0.614421
# 1     0.941574    0.911797    0.897809    0.877096  ...   0.619429
# 7      0.614517     0.598354     0.619020    0.568620
# 8      0.614939     0.595462     0.629501    0.569410
# 9      0.602155     0.600401     0.623896    0.566941
# 10     0.617064     0.608993     0.635434    0.583304
# 11     0.622853     0.605767     0.636509    0.584422
# 12     0.621484     0.606315     0.640778    0.581849
# 13     0.621259     0.605061     0.638708    0.583632
# 14     0.621812     0.609191     0.635624    0.582193
# 15     0.623398     0.609073     0.639075    0.585508
# 16     0.622313     0.608613     0.637135    0.584338
# 17     0.624090     0.607686     0.634359    0.583306
# 18     0.626764     0.603217     0.644483    0.584193
# 19     0.612868     0.606564     0.636836    0.582538
# 20     0.704763     0.694598     0.703002    0.687654
#
# [21 rows x 45 columns]

# %%
nameColumms=list(df)

# %%
res={}
for index,row in df.iterrows():
    l=list()
    for i in nameColumms[1:]:
        l.append(row[i])
    res[row['algoName']]=l

# %%
resultsf=resultFinal(res)
# Out:
# ['NMF']

# %%
resultsf
# Out:
# {'NMF': [1.2515771491852021,
#   1.336548023018124,
#   0.9655998846058256,
#   1.3670242311405003,
#   1.096268643694273,
#   1.0499286275420878,
#   1.0191516295928054,
#   1.0003002513335686,
#   0.9728308150988672,
#   0.9600465967686901,
#   0.9556417034120391,
#   0.9514034309579812,
#   0.9305725755983829,
#   0.9261647045493675,
#   0.9080107020331147,
#   0.9100916290522008,
#   0.9036974599045356,
#   0.9064374979185608,
#   0.9216620252543694,
#   0.8919612088403138,
#   0.9047947625643288,
#   0.8991027855276658,
#   0.9556166591289331,
#   1.0334576955042287,
#   0.7321822152180562,
#   1.0628937842671409,
#   0.8246212111034744,
#   0.7912360959628467,
#   0.7694553621296183,
#   0.754695470141529,
#   0.7345545684333177,
#   0.7226321763047363,
#   0.7268092134456383,
#   0.7198586053545812,
#   0.7052448123618761,
#   0.7057532140638503,
#   0.6946750192992878,
#   0.7001232001013996,
#   0.6922066948053458,
#   0.6977247604777665,
#   0.7076965059584513,
#   0.6865617071603074,
#   0.703364861070139,
#   0.6904331889711375]}

# %%
dfbis=pd.DataFrame(columns =nameColumms)
for key in resultsf:
    dfbis.loc[len(dfbis)]=[key]+resultsf[key]

# %%
dfbis.to_csv('data/resultRMSEbyInterval_V1.csv',index=False)

# %%
df2=dfbis.copy()

# %%
df2
# Out:
#   algoName  RMSE_All  RMSE_<20  RMSE_20+  RMSE_1-9  RMSE_10-19  RMSE_20-29  \
# 0      NMF  1.251577  1.336548    0.9656  1.367024    1.096269    1.049929
#
#    RMSE_30-39  RMSE_40-49  RMSE_50-59  ...  MAE_90-99  MAE_100-149  \
# 0    1.019152      1.0003    0.972831  ...   0.705245     0.705753
#
#    MAE_150-199  MAE_200-249  MAE_250-299  MAE_300-349  MAE_350-399  \
# 0     0.694675     0.700123     0.692207     0.697725     0.707697
#
#    MAE_400-449  MAE_450-499  MAE_sup500
# 0     0.686562     0.703365    0.690433
#
# [1 rows x 45 columns]
